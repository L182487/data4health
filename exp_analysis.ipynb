# %% [markdown]
# # Filtragem inicial de dados regionais do Global Health Data
#
# #### Fonte dos dados: Latin American Country HIV Mortality Geospatial Estimates by Age and Sex 2000-2017
# #### http://ghdx.healthdata.org/record/ihme-data/latin-america-hiv-mortality-geospatial-estimates-2000-2017

# %%
#tem que alterar isso pra ser válido pros datasets dos outros anos ( 2009 até 2017 )
import pandas as pd

df = pd.read_csv("data/Regionais 2009-2017/IHME_LA_HIV_MORT_2000_2017_RATE_ADMIN_2_2009_Y2020M08D13.CSV",
                usecols=['ADM0_NAME','ADM1_NAME','ADM2_NAME','year','age_group_name','sex','mean'])

df = df.rename(columns={'ADM0_NAME':'country','ADM1_NAME':'state','ADM2_NAME':'city','age_group_name':'age_group'})
print(df.shape)

df = df[df['country']=="Brazil"]
print(df.shape)
# Out:
# (553698, 7)
# (317490, 7)

# %% [markdown]
# ### Qual foi a localidade com a maior média de mortalidade de mulheres por HIV?

# %%
#print(df.drop_duplicates('state').head(5))

#Ainda tem que somar os valores por idade em cada cidade para confirmar

women = df[df['sex'] == 'Women']

print(women.loc[ (women['mean'].idxmax()) ] )
# Out:
# country                 Brazil
# state        Rio Grande do Sul
# city                 Tramandai
# year                      2009
# age_group             35 to 39
# sex                      Women
# mean                   73.4015
# Name: 288328, dtype: object

# %% [markdown]
# ### Qual foi a localidade com a maior média de mortalidade de homens por HIV?

# %%
#Ainda precisa fazer a mesma alteração do anterior

men = df[df['sex'] == 'Men']

print(men.loc[ (men['mean'].idxmax()) ])
# Out:
# country                 Brazil
# state        Rio Grande do Sul
# city                 Tramandai
# year                      2009
# age_group             35 to 39
# sex                        Men
# mean                   139.714
# Name: 288327, dtype: object

# %% [markdown]
# ### Quais foram as maiores taxas de mortalidade por HIV para cada faixa etária?

# %%
#Se não for analisar isto por localidade, ainda seria preciso somar TODAS as faixas etárias e remover as cidades

both_sexes = df[df['sex'] == 'Both']

both_sexes.sort_values('mean', ascending=False).drop_duplicates(['age_group'])
# Out:
#        country              state           city  year         age_group  \
# 288329  Brazil  Rio Grande do Sul      Tramandai  2009          35 to 39
# 252878  Brazil     Santa Catarina         Itajai  2009          40 to 44
# 252881  Brazil     Santa Catarina         Itajai  2009          45 to 49
# 288326  Brazil  Rio Grande do Sul      Tramandai  2009          30 to 34
# 252884  Brazil     Santa Catarina         Itajai  2009          50 to 54
# 252887  Brazil     Santa Catarina         Itajai  2009          55 to 59
# 288323  Brazil  Rio Grande do Sul      Tramandai  2009          25 to 29
# 252890  Brazil     Santa Catarina         Itajai  2009          60 to 64
# 288359  Brazil  Rio Grande do Sul      Tramandai  2009          All ages
# 288347  Brazil  Rio Grande do Sul      Tramandai  2009          65 to 69
# 288362  Brazil  Rio Grande do Sul      Tramandai  2009  Age-standardized
# 117764  Brazil              Bahia  Madre de Deus  2009            0 to 4
# ...
